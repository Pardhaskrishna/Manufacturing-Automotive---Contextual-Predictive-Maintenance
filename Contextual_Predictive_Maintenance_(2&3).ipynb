# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#read excel file
Data = pd.read_excel("/content/Predictive maintenance.xlsx")

# %%
Data
# Out:
#       Vehicle_ID  Mileage  Age  Maintenance_Frequency Engine_Type  \
# 0              1   122958    7                      9      Diesel
# 1              2   147867    4                      4      Diesel
# 2              3   132932   13                     10      Diesel
# 3              4   104694   13                      3      Diesel
# 4              5   120879   10                      8      Petrol
# ...          ...      ...  ...                    ...         ...
# 5495        5496   151872    7                     10      Diesel
# 5496        5497   129126   14                      8      Petrol
# 5497        5498   195472   11                      6      Diesel
# 5498        5499    93446    7                     10    Electric
# 5499        5500    30437   10                      7    Electric
#
#       Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# 0                     7              1286.78                  1
# ...

# %%
#info about columns and null values
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5500 entries, 0 to 5499
# Data columns (total 12 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Vehicle_ID                   5500 non-null   int64
#  1   Mileage                      5500 non-null   int64
#  2   Age                          5500 non-null   int64
#  3   Maintenance_Frequency        5500 non-null   int64
#  4   Engine_Type                  5500 non-null   object
#  5   Number_of_Repairs            5500 non-null   int64
#  6   Average_Repair_Cost          5500 non-null   float64
#  7   Critical_Failures            5500 non-null   int64
#  8   Last_Maintenance_Type        5500 non-null   object
#  9   Days_Since_Last_Maintenance  5500 non-null   int64
#  10  Vehicle_Usage                5500 non-null   object
#  11  Warning_Signals_Count        5500 non-null   int64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 515.8+ KB

# %%
#info about columns stattics
Data.describe()
# Out:
#         Vehicle_ID        Mileage          Age  Maintenance_Frequency  \
# count  5500.000000    5500.000000  5500.000000            5500.000000
# mean   2750.500000  101453.004727    10.112909               5.967636
# std    1587.857571   57549.265525     5.501887               3.123809
# min       1.000000    1126.000000     1.000000               1.000000
# 25%    1375.750000   51596.500000     5.000000               3.000000
# 50%    2750.500000  102300.000000    10.000000               6.000000
# 75%    4125.250000  151777.250000    15.000000               9.000000
# max    5500.000000  199986.000000    19.000000              11.000000
#
#        Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# count        5500.000000          5500.000000        5500.000000
# mean            4.460909           778.502804           2.030909
# std             2.879106           419.741886           1.410914
# min             0.000000            50.290000           0.000000
# ...

# %%
#info about varible
Data.dtypes
# Out:
# Vehicle_ID                       int64
# Mileage                          int64
# Age                              int64
# Maintenance_Frequency            int64
# Engine_Type                     object
# Number_of_Repairs                int64
# Average_Repair_Cost            float64
# Critical_Failures                int64
# Last_Maintenance_Type           object
# Days_Since_Last_Maintenance      int64
# Vehicle_Usage                   object
# Warning_Signals_Count            int64
# dtype: object

# %%
#check each column is null is their
Data.isnull()
# Out:
#       Vehicle_ID  Mileage    Age  Maintenance_Frequency  Engine_Type  \
# 0          False    False  False                  False        False
# 1          False    False  False                  False        False
# 2          False    False  False                  False        False
# 3          False    False  False                  False        False
# 4          False    False  False                  False        False
# ...          ...      ...    ...                    ...          ...
# 5495       False    False  False                  False        False
# 5496       False    False  False                  False        False
# 5497       False    False  False                  False        False
# 5498       False    False  False                  False        False
# 5499       False    False  False                  False        False
#
#       Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# 0                 False                False              False
# ...

# %%
#count isnull how many
Data.isnull().sum()
# Out:
# Vehicle_ID                     0
# Mileage                        0
# Age                            0
# Maintenance_Frequency          0
# Engine_Type                    0
# Number_of_Repairs              0
# Average_Repair_Cost            0
# Critical_Failures              0
# Last_Maintenance_Type          0
# Days_Since_Last_Maintenance    0
# Vehicle_Usage                  0
# Warning_Signals_Count          0
# dtype: int64

# %%
#check duplictes
Data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5495    False
# 5496    False
# 5497    False
# 5498    False
# 5499    False
# Length: 5500, dtype: bool

# %%
#count duplictes
Data.duplicated().sum()
# Out:
# np.int64(0)

# %%
Data.head()
# Out:
#    Vehicle_ID  Mileage  Age  Maintenance_Frequency Engine_Type  \
# 0           1   122958    7                      9      Diesel
# 1           2   147867    4                      4      Diesel
# 2           3   132932   13                     10      Diesel
# 3           4   104694   13                      3      Diesel
# 4           5   120879   10                      8      Petrol
#
#    Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# 0                  7              1286.78                  1
# 1                  4              1077.60                  4
# 2                  4              1339.85                  3
# 3                  1               458.33                  4
# 4                  7               554.78                  2
#
#   Last_Maintenance_Type  Days_Since_Last_Maintenance Vehicle_Usage  \
# 0          Engine check                           34    Commercial
# 1            Oil change                          288    Commercial
# ...

# %%
Data.tail()
# Out:
#       Vehicle_ID  Mileage  Age  Maintenance_Frequency Engine_Type  \
# 5495        5496   151872    7                     10      Diesel
# 5496        5497   129126   14                      8      Petrol
# 5497        5498   195472   11                      6      Diesel
# 5498        5499    93446    7                     10    Electric
# 5499        5500    30437   10                      7    Electric
#
#       Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# 5495                  9               687.60                  0
# 5496                  2              1134.75                  0
# 5497                  6              1267.91                  3
# 5498                  6              1396.29                  3
# 5499                  3               894.56                  2
#
#      Last_Maintenance_Type  Days_Since_Last_Maintenance Vehicle_Usage  \
# 5495          Engine check                          204      Personal
# ...

# %%
Data
# Out:
#       Vehicle_ID  Mileage  Age  Maintenance_Frequency Engine_Type  \
# 0              1   122958    7                      9      Diesel
# 1              2   147867    4                      4      Diesel
# 2              3   132932   13                     10      Diesel
# 3              4   104694   13                      3      Diesel
# 4              5   120879   10                      8      Petrol
# ...          ...      ...  ...                    ...         ...
# 5495        5496   151872    7                     10      Diesel
# 5496        5497   129126   14                      8      Petrol
# 5497        5498   195472   11                      6      Diesel
# 5498        5499    93446    7                     10    Electric
# 5499        5500    30437   10                      7    Electric
#
#       Number_of_Repairs  Average_Repair_Cost  Critical_Failures  \
# 0                     7              1286.78                  1
# ...

# %%
# second push

# %%
Data.columns
# Out:
# Index(['Vehicle_ID', 'Mileage', 'Age', 'Maintenance_Frequency', 'Engine_Type',
#        'Number_of_Repairs', 'Average_Repair_Cost', 'Critical_Failures',
#        'Last_Maintenance_Type', 'Days_Since_Last_Maintenance', 'Vehicle_Usage',
#        'Warning_Signals_Count'],
#       dtype='object')

# %%
sns.histplot(data=Data,x="Mileage")
# Out:
# <Axes: xlabel='Mileage', ylabel='Count'>

# %%
sns.histplot(data=Data,x="Average_Repair_Cost")
# Out:
# <Axes: xlabel='Average_Repair_Cost', ylabel='Count'>

# %%
sns.countplot(data=Data,x="Vehicle_Usage")
# Out:
# <Axes: xlabel='Vehicle_Usage', ylabel='count'>

# %%
Data.columns
# Out:
# Index(['Vehicle_ID', 'Mileage', 'Age', 'Maintenance_Frequency', 'Engine_Type',
#        'Number_of_Repairs', 'Average_Repair_Cost', 'Critical_Failures',
#        'Last_Maintenance_Type', 'Days_Since_Last_Maintenance', 'Vehicle_Usage',
#        'Warning_Signals_Count'],
#       dtype='object')

# %%
sns.scatterplot(data=Data,x="Vehicle_Usage",y="Mileage")
# Out:
# <Axes: xlabel='Vehicle_Usage', ylabel='Mileage'>

# %% [markdown]
# day 3 and day 4 push

# %%
Data.columns
# Out:
# Index(['Vehicle_ID', 'Mileage', 'Age', 'Maintenance_Frequency', 'Engine_Type',
#        'Number_of_Repairs', 'Average_Repair_Cost', 'Critical_Failures',
#        'Last_Maintenance_Type', 'Days_Since_Last_Maintenance', 'Vehicle_Usage',
#        'Warning_Signals_Count'],
#       dtype='object')

# %%
sns.histplot(data=Data,x="Average_Repair_Cost")
# Out:
# <Axes: xlabel='Average_Repair_Cost', ylabel='Count'>

# %%
sns.histplot(data=Data,x="Days_Since_Last_Maintenance")
# Out:
# <Axes: xlabel='Days_Since_Last_Maintenance', ylabel='Count'>

# %%
sns.boxplot(data=Data)
# Out:
# <Axes: >

# %%
sns.boxplot(data=Data,x="Mileage")
# Out:
# <Axes: xlabel='Mileage'>

# %%
Data.columns
# Out:
# Index(['Vehicle_ID', 'Mileage', 'Age', 'Maintenance_Frequency', 'Engine_Type',
#        'Number_of_Repairs', 'Average_Repair_Cost', 'Critical_Failures',
#        'Last_Maintenance_Type', 'Days_Since_Last_Maintenance', 'Vehicle_Usage',
#        'Warning_Signals_Count'],
#       dtype='object')

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2822/1465409315.py in <cell line: 0>()
#       1 X= Data.drop("Vehicle_Usage",axis=1)
# ----> 2 Y=Data("Mileage")
#
# TypeError: 'DataFrame' object is not callable
